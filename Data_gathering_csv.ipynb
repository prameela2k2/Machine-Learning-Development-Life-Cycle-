# %%
import pandas as pd

# %%
#local csv file
df=pd.read_csv('/content/purchase.csv - Sheet1 (4).csv')
df
# Out:
#     ID  Item Value  Discount (%)  Purchased
# 0    0         500            10          0
# 1    1         150             5          0
# 2    2         300            20          1
# 3    3        1000            15          1
# 4    4         750             8          0
# ..  ..         ...           ...        ...
# 95  95        1100             5          0
# 96  96         490            30          1
# 97  97         210            15          1
# 98  98         600            20          1
# 99  99         800            12          1
#
# [100 rows x 4 columns]

# %%
import requests
import pandas as pd
from io import StringIO

url = "https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master/Energy%20Level.csv"
headers = {"User-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}

req = requests.get(url, headers=headers)
data = StringIO(req.text)
df = pd.read_csv(data)

print(df)
# Out:
#     Group A  Group B
# 0         3        2
# 1         4        1
# 2         0        1
# 3         8        2
# 4         6        6
# ..      ...      ...
# 95        8        5
# 96        8        3
# 97        4        0
# 98        4        3
# 99        6        9
#
# [100 rows x 2 columns]

# %%
from google.colab import files
uploaded = files.upload()  # This will prompt you to upload the file
# Out:
#      <input type="file" id="files-0587bf18-5b59-499c-82a7-f616de6ce555" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0587bf18-5b59-499c-82a7-f616de6ce555">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'purchase.csv - Sheet1.tsv', 'purchase.csv - Sheet1 (1).tsv', 'purchase.csv - Sheet1 (4).csv', 'sample_data']

# %%
pd.read_csv('/content/purchase.csv - Sheet1.tsv')
# Out:
#    ID\tItem Value\tDiscount (%)\tPurchased
# 0                            0\t500\t10\t0
# 1                             1\t150\t5\t0
# 2                            2\t300\t20\t1
# 3                           3\t1000\t15\t1
# 4                             4\t750\t8\t0
# ..                                     ...
# 95                          95\t1100\t5\t0
# 96                          96\t490\t30\t1
# 97                          97\t210\t15\t1
# 98                          98\t600\t20\t1
# 99                          99\t800\t12\t1
#
# [100 rows x 1 columns]

# %%
#tab separated value
df = pd.read_csv('/content/purchase.csv - Sheet1.tsv', sep='\t')
print(df.head())
# Out:
#    ID  Item Value  Discount (%)  Purchased
# 0   0         500            10          0
# 1   1         150             5          0
# 2   2         300            20          1
# 3   3        1000            15          1
# 4   4         750             8          0

# %%
#do this if no names are defined.
df = pd.read_csv('/content/purchase.csv - Sheet1.tsv', sep='\t',names=['sno','ID','Item Value','Discount (%)','Purchased'])
print(df.head())
# Out:
#   sno          ID    Item Value Discount (%)  Purchased
# 0  ID  Item Value  Discount (%)    Purchased        NaN
# 1   0         500            10            0        NaN
# 2   1         150             5            0        NaN
# 3   2         300            20            1        NaN
# 4   3        1000            15            1        NaN
